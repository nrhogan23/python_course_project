# %%
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# I began by importing the integral elements of the program

# %%
with open('bestsellers_with_categories.csv', 'r') as datafile:
    amazon_data = csv.DictReader(datafile)
    data_list = []
    
    for row in amazon_data:
        data_list.append(row)

# %% [markdown]
# I then want the program to read the data file in my folder, I also want to create a varaible for the data, which I labeled amazon_data, as well as creating a now blank list. Finally, I used a for loop to introduce the data into my newly created data_list variable, as this will make it much easier to work with.

# %%
nonfiction_book_data = {}

for item in data_list:
    if item['Genre'] == 'Non Fiction':
        if not nonfiction_book_data.get(item['Name']):
            nonfiction_book_data[ item['Name']] = {}
        entry = {
            'Year on the Bestsellers List': item['Year'],
            'Nonfiction Reviews': item['User Rating']
        }
        nonfiction_book_data[ item['Name']] = entry

nonfiction_book_data
# Out:
# {'10-Day Green Smoothie Cleanse': {'Year on the Bestsellers List': '2016',
#   'Nonfiction Reviews': '4.7'},
#  '12 Rules for Life: An Antidote to Chaos': {'Year on the Bestsellers List': '2018',
#   'Nonfiction Reviews': '4.7'},
#  '5,000 Awesome Facts (About Everything!) (National Geographic Kids)': {'Year on the Bestsellers List': '2019',
#   'Nonfiction Reviews': '4.8'},
#  'A Higher Loyalty: Truth, Lies, and Leadership': {'Year on the Bestsellers List': '2018',
#   'Nonfiction Reviews': '4.7'},
#  "A Patriot's History of the United States: From Columbus's Great Discovery to the War on Terror": {'Year on the Bestsellers List': '2010',
#   'Nonfiction Reviews': '4.6'},
#  'A Stolen Life: A Memoir': {'Year on the Bestsellers List': '2011',
#   'Nonfiction Reviews': '4.6'},
#  'Act Like a Lady, Think Like a Man: What Men Really Think About Love, Relationships, Intimacy, and Commitment': {'Year on the Bestsellers List': '2009',
#   'Nonfiction Reviews': '4.6'},
# ...

# %% [markdown]
# I had to parse through the data, first I want to ensure that I was only looking at the data for nonfiction books. I then wanted to extract each datapoint, so to ensure I had a rating for every book, I listed each by their title. I then wanted wanted to display the year on the bestseller list and average user rating for each book, so I added them to the entry varaible, which I then set equal to the the dictionary nonfiction_book_data. Finally I called the dictionary by writing out it's name.

# %%
plt.title('Average User Rating for Bestselling Nonfiction Works')
plt.xlabel('Year')
plt.ylabel('Average User Rating')

x = ["2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"]

for item in data_list:
    if item['Year'] == '2009':
        nonfiction_book_data[item["User Score"/50]] = da
    elif item['Year'] == '2010':
        nonfiction_book_data[item['User Score'/50]] = db
    elif item['Year'] == '2011':
        nonfiction_book_data[item['User Score'/50]] = dc
    elif item['Year'] == '2012':
        nonfiction_book_data[item['User Score'/50]] = dd
    elif item['Year'] == '2013':
        nonfiction_book_data[item['User Score'/50]] = de
    elif item['Year'] == '2014':
        nonfiction_book_data[item['User Score'/50]] = df
    elif item['Year'] == '2015':
        nonfiction_book_data[item['User Score'/50]] = dg
    elif item['Year'] == '2016':
        nonfiction_book_data[item['User Score'/50]] = dh
    elif item['Year'] == '2017':
        nonfiction_book_data[item['User Score'/50]] = di
    elif item['Year'] == '2018':
        nonfiction_book_data[item['User Score'/50]] = dj
    elif item['Year'] == '2019':
        nonfiction_book_data[item['User Score'/50]] = dk
        
y = [da, db, dc, dd, de, df, dg, dh, di, dj, dk]

plt.bar(x, y)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-b2d0daf4331f> in <module>
#      21         nonfiction_book_data[item['User Score'/50]] = dg
#      22     elif item['Year'] == '2016':
# ---> 23         nonfiction_book_data[item['User Score'/50]] = dh
#      24     elif item['Year'] == '2017':
#      25         nonfiction_book_data[item['User Score'/50]] = di
#
# NameError: name 'dh' is not defined
